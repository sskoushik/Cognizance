# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("https://raw.githubusercontent.com/cognizance-amrita/AI-Tasks/main/Task-1/Q2-Dataset.csv")

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... MasVnrArea ExterQual ExterCond Foundation  \
# 0         Lvl    AllPub  ...        196        Gd        TA      PConc
# 1         Lvl    AllPub  ...          0        TA        TA     CBlock
# 2         Lvl    AllPub  ...        162        Gd        TA      PConc
# 3         Lvl    AllPub  ...          0        TA        TA     BrkTil
# 4         Lvl    AllPub  ...        350        Gd        TA      PConc
#
#   BsmtQual BsmtCond BsmtExposure  BsmtFinType1  BsmtFinSF1  BsmtFinType2
# 0       Gd       TA           No           GLQ         706           Unf
# 1       Gd       TA           Gd           ALQ         978           Unf
# 2       Gd       TA           Mn           GLQ         486           Unf
# 3       TA       Gd           No           ALQ         216           Unf
# 4       Gd       TA           Av           GLQ         655           Unf
#
# [5 rows x 36 columns]

# %%
missing_value_formats = ["n.a.","?","NA","n/a", "na", "--"]
df = pd.read_csv("https://raw.githubusercontent.com/cognizance-amrita/AI-Tasks/main/Task-1/Q2-Dataset.csv", na_values = missing_value_formats)

# %%
print(df.isnull().sum())
# Out:
# Id               0
# MSSubClass       0
# MSZoning         0
# LotFrontage     14
# LotArea          0
# Street           0
# Alley           93
# LotShape         0
# LandContour      0
# Utilities        0
# LotConfig        0
# LandSlope        0
# Neighborhood     0
# Condition1       0
# Condition2       0
# BldgType         0
# HouseStyle       0
# OverallQual      0
# OverallCond      0
# YearBuilt        0
# YearRemodAdd     0
# RoofStyle        0
# RoofMatl         0
# Exterior1st      0
# Exterior2nd      0
# MasVnrType       0
# MasVnrArea       0
# ExterQual        0
# ExterCond        0
# Foundation       0
# BsmtQual         3
# BsmtCond         3
# BsmtExposure     3
# BsmtFinType1     3
# BsmtFinSF1       0
# BsmtFinType2     3
# dtype: int64

# %%
df['LotFrontage'].fillna(1, inplace=True)

# %%
print(df['LotFrontage'])
# Out:
# 0     65.0
# 1     80.0
# 2     68.0
# 3     60.0
# 4     84.0
#       ...
# 94    69.0
# 95     1.0
# 96    78.0
# 97    73.0
# 98    85.0
# Name: LotFrontage, Length: 99, dtype: float64

# %%
print(df['Alley'].isnull())
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
#       ...
# 94    True
# 95    True
# 96    True
# 97    True
# 98    True
# Name: Alley, Length: 99, dtype: bool

# %%
df['Alley'].fillna('no alley name mentioned', inplace=True)
print(df['Alley'])
# Out:
# 0     no alley name mentioned
# 1     no alley name mentioned
# 2     no alley name mentioned
# 3     no alley name mentioned
# 4     no alley name mentioned
#                ...
# 94    no alley name mentioned
# 95    no alley name mentioned
# 96    no alley name mentioned
# 97    no alley name mentioned
# 98    no alley name mentioned
# Name: Alley, Length: 99, dtype: object

# %%
print(df['BsmtQual'].isnull())
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 94    False
# 95    False
# 96    False
# 97    False
# 98    False
# Name: BsmtQual, Length: 99, dtype: bool

# %%
df[df['BsmtQual'].isnull()]
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street  \
# 17  18          90       RL         72.0    10791   Pave
# 39  40          90       RL         65.0     6040   Pave
# 90  91          20       RL         60.0     7200   Pave
#
#                       Alley LotShape LandContour Utilities  ... MasVnrArea  \
# 17  no alley name mentioned      Reg         Lvl    AllPub  ...          0
# 39  no alley name mentioned      Reg         Lvl    AllPub  ...          0
# 90  no alley name mentioned      Reg         Lvl    AllPub  ...          0
#
#    ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 17        TA        TA       Slab      NaN      NaN          NaN
# 39        TA        TA      PConc      NaN      NaN          NaN
# 90        TA        TA       Slab      NaN      NaN          NaN
#
#     BsmtFinType1  BsmtFinSF1  BsmtFinType2
# 17           NaN           0           NaN
# 39           NaN           0           NaN
# 90           NaN           0           NaN
#
# [3 rows x 36 columns]

# %%
df['BsmtQual'].fillna('3', inplace=True)

# %%
df[df['BsmtQual'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotFrontage, LotArea, Street, Alley, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2]
# Index: []
#
# [0 rows x 36 columns]

# %%
print(df['BsmtCond'].isnull())
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 94    False
# 95    False
# 96    False
# 97    False
# 98    False
# Name: BsmtCond, Length: 99, dtype: bool

# %%
df[df['BsmtCond'].isnull()]
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street  \
# 17  18          90       RL         72.0    10791   Pave
# 39  40          90       RL         65.0     6040   Pave
# 90  91          20       RL         60.0     7200   Pave
#
#                       Alley LotShape LandContour Utilities  ... MasVnrArea  \
# 17  no alley name mentioned      Reg         Lvl    AllPub  ...          0
# 39  no alley name mentioned      Reg         Lvl    AllPub  ...          0
# 90  no alley name mentioned      Reg         Lvl    AllPub  ...          0
#
#    ExterQual ExterCond Foundation             BsmtQual BsmtCond BsmtExposure  \
# 17        TA        TA       Slab  no value given here      NaN          NaN
# 39        TA        TA      PConc  no value given here      NaN          NaN
# 90        TA        TA       Slab  no value given here      NaN          NaN
#
#     BsmtFinType1  BsmtFinSF1  BsmtFinType2
# 17           NaN           0           NaN
# 39           NaN           0           NaN
# 90           NaN           0           NaN
#
# [3 rows x 36 columns]

# %%
df['BsmtCond'].fillna('78', inplace=True)

# %%
df[df['BsmtCond'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotFrontage, LotArea, Street, Alley, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2]
# Index: []
#
# [0 rows x 36 columns]

# %%
print(df['BsmtExposure'].isnull())
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 94    False
# 95    False
# 96    False
# 97    False
# 98    False
# Name: BsmtExposure, Length: 99, dtype: bool

# %%
df[df['BsmtExposure'].isnull()]
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street  \
# 17  18          90       RL         72.0    10791   Pave
# 39  40          90       RL         65.0     6040   Pave
# 90  91          20       RL         60.0     7200   Pave
#
#                       Alley LotShape LandContour Utilities  ... MasVnrArea  \
# 17  no alley name mentioned      Reg         Lvl    AllPub  ...          0
# 39  no alley name mentioned      Reg         Lvl    AllPub  ...          0
# 90  no alley name mentioned      Reg         Lvl    AllPub  ...          0
#
#    ExterQual ExterCond Foundation             BsmtQual BsmtCond BsmtExposure  \
# 17        TA        TA       Slab  no value given here     None          NaN
# 39        TA        TA      PConc  no value given here     None          NaN
# 90        TA        TA       Slab  no value given here     None          NaN
#
#     BsmtFinType1  BsmtFinSF1  BsmtFinType2
# 17           NaN           0           NaN
# 39           NaN           0           NaN
# 90           NaN           0           NaN
#
# [3 rows x 36 columns]

# %%
df['BsmtExposure'].fillna('no exposure mentioned', inplace=True)

# %%
df[df['BsmtExposure'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotFrontage, LotArea, Street, Alley, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2]
# Index: []
#
# [0 rows x 36 columns]

# %%
print(df['BsmtFinType1'].isnull())
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 94    False
# 95    False
# 96    False
# 97    False
# 98    False
# Name: BsmtFinType1, Length: 99, dtype: bool

# %%
df[df['BsmtFinType1'].isnull()]
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street  \
# 17  18          90       RL         72.0    10791   Pave
# 39  40          90       RL         65.0     6040   Pave
# 90  91          20       RL         60.0     7200   Pave
#
#                       Alley LotShape LandContour Utilities  ... MasVnrArea  \
# 17  no alley name mentioned      Reg         Lvl    AllPub  ...          0
# 39  no alley name mentioned      Reg         Lvl    AllPub  ...          0
# 90  no alley name mentioned      Reg         Lvl    AllPub  ...          0
#
#    ExterQual ExterCond Foundation             BsmtQual BsmtCond  \
# 17        TA        TA       Slab  no value given here     None
# 39        TA        TA      PConc  no value given here     None
# 90        TA        TA       Slab  no value given here     None
#
#          BsmtExposure  BsmtFinType1  BsmtFinSF1  BsmtFinType2
# 17  No given exposure           NaN           0           NaN
# 39  No given exposure           NaN           0           NaN
# 90  No given exposure           NaN           0           NaN
#
# [3 rows x 36 columns]

# %%
df['BsmtFinType1'].fillna('Values not mentioned', inplace=True)

# %%
df[df['BsmtFinType1'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotFrontage, LotArea, Street, Alley, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2]
# Index: []
#
# [0 rows x 36 columns]

# %%
print(df['BsmtFinType2'].isnull())
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 94    False
# 95    False
# 96    False
# 97    False
# 98    False
# Name: BsmtFinType2, Length: 99, dtype: bool

# %%
df[df['BsmtFinType2'].isnull()]
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street  \
# 17  18          90       RL         72.0    10791   Pave
# 39  40          90       RL         65.0     6040   Pave
# 90  91          20       RL         60.0     7200   Pave
#
#                       Alley LotShape LandContour Utilities  ... MasVnrArea  \
# 17  no alley name mentioned      Reg         Lvl    AllPub  ...          0
# 39  no alley name mentioned      Reg         Lvl    AllPub  ...          0
# 90  no alley name mentioned      Reg         Lvl    AllPub  ...          0
#
#    ExterQual ExterCond Foundation             BsmtQual BsmtCond  \
# 17        TA        TA       Slab  no value given here     None
# 39        TA        TA      PConc  no value given here     None
# 90        TA        TA       Slab  no value given here     None
#
#          BsmtExposure              BsmtFinType1  BsmtFinSF1  BsmtFinType2
# 17  No given exposure  Values yet to be updated           0           NaN
# 39  No given exposure  Values yet to be updated           0           NaN
# 90  No given exposure  Values yet to be updated           0           NaN
#
# [3 rows x 36 columns]

# %%
df['BsmtFinType2'].fillna('57', inplace=True)

# %%
df[df['BsmtFinType2'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotFrontage, LotArea, Street, Alley, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2]
# Index: []
#
# [0 rows x 36 columns]

# %%
print(df.isnull().sum())
# Out:
# Id              0
# MSSubClass      0
# MSZoning        0
# LotFrontage     0
# LotArea         0
# Street          0
# Alley           0
# LotShape        0
# LandContour     0
# Utilities       0
# LotConfig       0
# LandSlope       0
# Neighborhood    0
# Condition1      0
# Condition2      0
# BldgType        0
# HouseStyle      0
# OverallQual     0
# OverallCond     0
# YearBuilt       0
# YearRemodAdd    0
# RoofStyle       0
# RoofMatl        0
# Exterior1st     0
# Exterior2nd     0
# MasVnrType      0
# MasVnrArea      0
# ExterQual       0
# ExterCond       0
# Foundation      0
# BsmtQual        0
# BsmtCond        0
# BsmtExposure    0
# BsmtFinType1    0
# BsmtFinSF1      0
# BsmtFinType2    0
# dtype: int64
